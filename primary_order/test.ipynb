# %% [markdown]
# # R test

# %%
library(ggplot2)
# Out:
# Loading required package: digest
# Loading required package: grid
# Loading required package: gtable
# Loading required package: MASS
# Loading required package: plyr
# Loading required package: Rcpp
# Loading required package: reshape2
# Loading required package: stringr
# Loading required package: lattice
# Loading required package: scales
# Loading required package: RColorBrewer
# Loading required package: dichromat
# Loading required package: munsell
# Loading required package: colorspace
# Loading required package: labeling

# %%
example(geom_point)
# Out:
# gm_pnt> p <- ggplot(mtcars, aes(wt, mpg))
#
# gm_pnt> p + geom_point()
# gm_pnt> # Add aesthetic mappings
# gm_pnt> p + geom_point(aes(colour = factor(cyl)))
# gm_pnt> p + geom_point(aes(shape = factor(cyl)))
# gm_pnt> p + geom_point(aes(size = qsec))
# gm_pnt> # Change scales
# gm_pnt> p + geom_point(aes(colour = cyl)) + scale_colour_gradient(low = "blue")
# gm_pnt> p + geom_point(aes(shape = factor(cyl))) + scale_shape(solid = FALSE)
# gm_pnt> # Set aesthetics to fixed value
# gm_pnt> ggplot(mtcars, aes(wt, mpg)) + geom_point(colour = "red", size = 3)
# gm_pnt> ## No test:
# gm_pnt> ##D # Varying alpha is useful for large datasets
# gm_pnt> ##D d <- ggplot(diamonds, aes(carat, price))
# gm_pnt> ##D d + geom_point(alpha = 1/10)
# gm_pnt> ##D d + geom_point(alpha = 1/20)
# gm_pnt> ##D d + geom_point(alpha = 1/100)
# gm_pnt> ## End(No test)
# gm_pnt>
# gm_pnt> # For shapes that have a border (like 21), you can colour the inside and
# ...
